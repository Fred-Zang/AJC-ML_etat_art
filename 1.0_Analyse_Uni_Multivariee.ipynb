# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Variable discrète

# %%
df["sex"].value_counts(normalize=True, sort= True, ascending=False)
# Out:
# sex
# Male      0.643443
# Female    0.356557
# Name: proportion, dtype: float64

# %%
df["sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
sns.countplot(data=df, x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # Variable Continue

# %%
df["tip"].mean()
# Out:
# np.float64(2.99827868852459)

# %%
df["tip"].min()
# Out:
# np.float64(1.0)

# %%
df["tip"].max()
# Out:
# np.float64(10.0)

# %%
df["tip"].median()
# Out:
# np.float64(2.9)

# %%
df["tip"].quantile(0.25)
# Out:
# np.float64(2.0)

# %%
df["tip"].var()
# Out:
# np.float64(1.914454638062471)

# %%
df["tip"].std()
# Out:
# np.float64(1.3836381890011822)

# %%
df["tip"].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %% [markdown]
# # Histogramme

# %%
df["tip"].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(data=df, x="tip", bins=10)

# %% [markdown]
# # Boxplot

# %%
df["tip"].plot(kind="box")
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 2))
sns.boxplot(x=df["tip"])
plt.show()

# %% [markdown]
# # mieux en 2 graphes sur le meme axe

# %%
plt.figure(figsize=(12,8))

fig, ax = plt.subplots(2,1,sharex=True)
sns.histplot(data=df, x="tip", ax= ax[0])
sns.boxplot(data=df, x="tip", ax= ax[1])
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# # Analyse Multivariée

# %% [markdown]
# ## Discret / Discret

# %%
pd.crosstab(df["sex"], df["smoker"])
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
pd.crosstab(df["size"], df["day"], normalize=True)
# Out:
# day       Thur       Fri       Sat       Sun
# size
# 1     0.004098  0.004098  0.008197  0.000000
# 2     0.196721  0.065574  0.217213  0.159836
# 3     0.016393  0.004098  0.073770  0.061475
# 4     0.020492  0.004098  0.053279  0.073770
# 5     0.004098  0.000000  0.004098  0.012295
# 6     0.012295  0.000000  0.000000  0.004098

# %% [markdown]
# ## Heatmap / crosstab

# %%
sns.heatmap(pd.crosstab(df["size"], df["day"]), annot=True)
# Out:
# <Axes: xlabel='day', ylabel='size'>

# %% [markdown]
# # Discret / Continue

# %%
df.groupby("sex")["tip"].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2192\193511169.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("sex")["tip"].mean()
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
df.groupby("sex")["tip"].describe()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2192\199809758.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("sex")["tip"].describe()
#         count      mean       std  min  25%   50%   75%   max
# sex
# Male    157.0  3.089618  1.489102  1.0  2.0  3.00  3.76  10.0
# Female   87.0  2.833448  1.159495  1.0  2.0  2.75  3.50   6.5

# %% [markdown]
# ## Plotbar Catplot Displot boxplot

# %%
df.groupby("sex")["tip"].mean().plot(kind="bar")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2192\29105690.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("sex")["tip"].mean().plot(kind="bar")
# <Axes: xlabel='sex'>

# %%
sns.catplot(data=df, x="sex", y="tip", kind="bar")

# %%
sns.displot(data=df, x="tip", hue="sex")

# %%
sns.boxplot(data=df, x="tip", y="sex", hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %% [markdown]
# # continue / continue
#
# ## Scatterplot pairplot

# %%
sns.scatterplot(data=df, x="tip", y="total_bill")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.pairplot(data=df, hue="size")

# %%
sns.pairplot(data=df, hue="sex")
